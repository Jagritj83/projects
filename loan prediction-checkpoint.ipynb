# %% [markdown]
# # Loan Application Status Prediction

# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
# Importing Loan Predication CSV dataset file using pandas
df=pd.read_csv('C:\\Users\\jagri\\Downloads\\loan_prediction.csv')

# %%
print('No of Rows:',df.shape[0])
print('No. of Columns:',df.shape[1])
df.head()
# Out:
# No of Rows: 614
# No. of Columns: 13
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.duplicated().sum() # This check any if any duplicated entry exit in dataset
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                    Missing Values  % Missing data
# Credit_History                 50        8.143322
# Self_Employed                  32        5.211726
# LoanAmount                     22        3.583062
# Dependents                     15        2.442997
# Loan_Amount_Term               14        2.280130
# Gender                         13        2.117264
# Married                         3        0.488599
# Loan_ID                         0        0.000000
# Education                       0        0.000000
# ApplicantIncome                 0        0.000000
# CoapplicantIncome               0        0.000000
# Property_Area                   0        0.000000
# Loan_Status                     0        0.000000

# %%
category=['Gender','Married','Dependents','Education','Self_Employed',
          'Loan_Amount_Term','Property_Area','Credit_History','Loan_Status']
for i in category:
    print(i)
    print(df[i].value_counts())
    print('='*100)
# Out:
# Gender
# Male      489
# Female    112
# Name: Gender, dtype: int64
# ====================================================================================================
# Married
# Yes    398
# No     213
# Name: Married, dtype: int64
# ====================================================================================================
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64
# ====================================================================================================
# Education
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
# ====================================================================================================
# Self_Employed
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64
# ====================================================================================================
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64
# ====================================================================================================
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
# ====================================================================================================
# Credit_History
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64
# ====================================================================================================
# Loan_Status
# Y    422
# N    192
# Name: Loan_Status, dtype: int64
# ====================================================================================================

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,20),facecolor='white')
plotnumber=1
category=['Gender','Married','Dependents','Education','Self_Employed',
          'Loan_Amount_Term','Property_Area','Credit_History','Loan_Status']
for i in category:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.countplotx=(df[i])
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.boxplot( y='LoanAmount', data=df,color='cyan')
plt.ylabel('Loan Amount',fontsize=15)
plt.subplot(1,2,2)
sns.distplot(df['LoanAmount'], color='b')
plt.xlabel('Loan Amount',fontsize=15)
plt.tight_layout()
plt.show()

# %%
print("Mean of Loan Amount:",df['LoanAmount'].mean())
print("Median of Loan Amount:",df['LoanAmount'].median())
# Out:
# Mean of Loan Amount: 146.41216216216216
# Median of Loan Amount: 128.0

# %%
# Imputating Missing value with mode for categorical features
df['Credit_History'].fillna(df['Credit_History'].mode()[0],inplace=True)
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0],inplace=True)
df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)
df['Married'].fillna(df['Married'].mode()[0],inplace=True)

# Imputation of Numerical features
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0],inplace=True)
df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                    Missing Values  % Missing data
# Loan_ID                         0             0.0
# Gender                          0             0.0
# Married                         0             0.0
# Dependents                      0             0.0
# Education                       0             0.0
# Self_Employed                   0             0.0
# ApplicantIncome                 0             0.0
# CoapplicantIncome               0             0.0
# LoanAmount                      0             0.0
# Loan_Amount_Term                0             0.0
# Credit_History                  0             0.0
# Property_Area                   0             0.0
# Loan_Status                     0             0.0

# %% [markdown]
# Comment :
# Finally, No Missing Value is Present.
#
# We are Now Yes To Go Further !!!

# %% [markdown]
# # Statistical Matrix

# %%
# Visualizing the statistics of the columns using heatmap.
plt.figure(figsize=(12,8))
sns.heatmap(df.describe(),linewidths = 0.1,fmt='0.1f',annot = True,cmap='PiYG')
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  145.752443        342.410423
# std        6109.041673        2926.248369   84.107233         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  128.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# Comment:
# In Applicant Income & Coapplicant Income Std deviation value is greater than median. So data is spread and skewed.
# Taking 75% and Max rows into consideration we can surely say that Outliers exist in Applicant Income, Coapplicant Income,Loan Amount.
# Since Credit History is Categorical variable there is no significance in different statstical parameter of it.
# Minimum Tenure for Loan is 12 Months and Maximum Loan tenure is 480 Months.
# Minimum Applicant income is 150 and maximum is 81000.
# Let dive into exploration of Target and independent feature.

# %% [markdown]
# # Target Variable

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Loan_Status'].value_counts().plot.pie(explode=[0,0.1],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Loan Status', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot(x='Loan_Status',data=df,ax=ax[1])
ax[1].set_title('Loan Status',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Loan Status",fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# Comment :
# 68.7% Applicants gets loan Approval.
# We can see that dataset is imbalanced in nature.
# Let check each feature against Target variable to gain insight into data.

# %% [markdown]
# # Gender Vs Loan Status

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(16,8))
df['Gender'].value_counts().plot.pie(explode=[0,0.1],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Gender', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot(x='Gender',hue="Loan_Status",data=df,ax=ax[1])
ax[1].set_title('Gender Vs Loan Status',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Loan Status",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
pd.crosstab(df['Gender'],df["Loan_Status"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c5fc9_row0_col0, #T_c5fc9_row0_col1, #T_c5fc9_row0_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_c5fc9_row1_col0 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_c5fc9_row1_col1 {
#   background-color: #379b66;
#   color: #f1f1f1;
# }
# #T_c5fc9_row1_col2 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_c5fc9_row2_col0, #T_c5fc9_row2_col1, #T_c5fc9_row2_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c5fc9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Loan_Status</th>
#       <th id="T_c5fc9_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_c5fc9_level0_col1" class="col_heading level0 col1" >Y</th>
#       <th id="T_c5fc9_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5fc9_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_c5fc9_row0_col0" class="data row0 col0" >37</td>
#       <td id="T_c5fc9_row0_col1" class="data row0 col1" >75</td>
#       <td id="T_c5fc9_row0_col2" class="data row0 col2" >112</td>
#     </tr>
#     <tr>
#       <th id="T_c5fc9_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_c5fc9_row1_col0" class="data row1 col0" >155</td>
#       <td id="T_c5fc9_row1_col1" class="data row1 col1" >347</td>
#       <td id="T_c5fc9_row1_col2" class="data row1 col2" >502</td>
#     </tr>
#     <tr>
#       <th id="T_c5fc9_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_c5fc9_row2_col0" class="data row2 col0" >192</td>
#       <td id="T_c5fc9_row2_col1" class="data row2 col1" >422</td>
#       <td id="T_c5fc9_row2_col2" class="data row2 col2" >614</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Comment :
# 81.8% Applicant are male.
# Irrespective Gender 65 % Applicant from each gender gets loan approval.It means that gender doesnot play any role loan approval. No Discrimation on name of Gender done

# %% [markdown]
# # Married Vs Loan Status

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(16,8))
df['Married'].value_counts().plot.pie(explode=[0,0.1],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Married', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot(x='Married',hue="Loan_Status",data=df,ax=ax[1])
ax[1].set_title('Married Vs Loan Status',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Married",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
pd.crosstab([df['Gender'],df['Married']],[df.Loan_Status],margins=True).style.background_gradient(cmap='gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_e17c3_row0_col0 {
#   background-color: #a100ff;
#   color: #f1f1f1;
# }
# #T_e17c3_row0_col1 {
#   background-color: #e200ff;
#   color: #f1f1f1;
# }
# #T_e17c3_row0_col2 {
#   background-color: #cd00ff;
#   color: #f1f1f1;
# }
# #T_e17c3_row1_col0, #T_e17c3_row1_col1, #T_e17c3_row1_col2 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_e17c3_row2_col0 {
#   background-color: #0400ff;
#   color: #f1f1f1;
# }
# #T_e17c3_row2_col1 {
#   background-color: #7600ff;
#   color: #f1f1f1;
# }
# #T_e17c3_row2_col2 {
#   background-color: #5000ff;
#   color: #f1f1f1;
# }
# #T_e17c3_row3_col0 {
#   background-color: #00ff66;
#   color: #000000;
# }
# #T_e17c3_row3_col1 {
#   background-color: #05ff00;
#   color: #000000;
# }
# #T_e17c3_row3_col2 {
#   background-color: #00ff1b;
#   color: #000000;
# }
# #T_e17c3_row4_col0, #T_e17c3_row4_col1, #T_e17c3_row4_col2 {
#   background-color: #ff0029;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e17c3">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Loan_Status</th>
#       <th id="T_e17c3_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_e17c3_level0_col1" class="col_heading level0 col1" >Y</th>
#       <th id="T_e17c3_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="index_name level1" >Married</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e17c3_level0_row0" class="row_heading level0 row0" rowspan="2">Female</th>
#       <th id="T_e17c3_level1_row0" class="row_heading level1 row0" >No</th>
#       <td id="T_e17c3_row0_col0" class="data row0 col0" >29</td>
#       <td id="T_e17c3_row0_col1" class="data row0 col1" >51</td>
#       <td id="T_e17c3_row0_col2" class="data row0 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_e17c3_level1_row1" class="row_heading level1 row1" >Yes</th>
#       <td id="T_e17c3_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_e17c3_row1_col1" class="data row1 col1" >24</td>
#       <td id="T_e17c3_row1_col2" class="data row1 col2" >32</td>
#     </tr>
#     <tr>
#       <th id="T_e17c3_level0_row2" class="row_heading level0 row2" rowspan="2">Male</th>
#       <th id="T_e17c3_level1_row2" class="row_heading level1 row2" >No</th>
#       <td id="T_e17c3_row2_col0" class="data row2 col0" >50</td>
#       <td id="T_e17c3_row2_col1" class="data row2 col1" >83</td>
#       <td id="T_e17c3_row2_col2" class="data row2 col2" >133</td>
#     </tr>
#     <tr>
#       <th id="T_e17c3_level1_row3" class="row_heading level1 row3" >Yes</th>
#       <td id="T_e17c3_row3_col0" class="data row3 col0" >105</td>
#       <td id="T_e17c3_row3_col1" class="data row3 col1" >264</td>
#       <td id="T_e17c3_row3_col2" class="data row3 col2" >369</td>
#     </tr>
#     <tr>
#       <th id="T_e17c3_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_e17c3_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_e17c3_row4_col0" class="data row4 col0" >192</td>
#       <td id="T_e17c3_row4_col1" class="data row4 col1" >422</td>
#       <td id="T_e17c3_row4_col2" class="data row4 col2" >614</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Comment:
# 65.3 % loan applicants are married. We can see from Count plot that Married people have more possibility of getting loan approval.
# But Here comes Interesting observation from crosstab :
# Unmarried Women are more chances of getting loan approval compare to married women.We will try to find which factor actually play deciding role here like education, employeement or Income.
# Married Men are more chances of loan approval.

# %% [markdown]
# # Let check how number dependents play here

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2')
f,ax=plt.subplots(1,2,figsize=(16,8))
df['Dependents'].value_counts().plot.pie(explode=[0,0.1,0.15,0.2],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('No. of Dependents', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot(x='Dependents',hue="Loan_Status",data=df,ax=ax[1])
ax[1].set_title('No. of Dependents Vs Loan Status',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Dependents",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
pd.crosstab([df['Dependents']],[df.Loan_Status,df['Gender']],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_3b1dd_row0_col0 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# #T_3b1dd_row0_col1 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_3b1dd_row0_col2 {
#   background-color: #41a066;
#   color: #f1f1f1;
# }
# #T_3b1dd_row0_col3 {
#   background-color: #7ebe66;
#   color: #000000;
# }
# #T_3b1dd_row0_col4 {
#   background-color: #73b966;
#   color: #f1f1f1;
# }
# #T_3b1dd_row1_col0 {
#   background-color: #e2f066;
#   color: #000000;
# }
# #T_3b1dd_row1_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_3b1dd_row1_col2 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_3b1dd_row1_col3 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_3b1dd_row1_col4 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_3b1dd_row2_col0, #T_3b1dd_row3_col0, #T_3b1dd_row3_col1, #T_3b1dd_row3_col2, #T_3b1dd_row3_col3, #T_3b1dd_row3_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_3b1dd_row2_col1 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_3b1dd_row2_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_3b1dd_row2_col3 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_3b1dd_row2_col4 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_3b1dd_row4_col0, #T_3b1dd_row4_col1, #T_3b1dd_row4_col2, #T_3b1dd_row4_col3, #T_3b1dd_row4_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3b1dd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Loan_Status</th>
#       <th id="T_3b1dd_level0_col0" class="col_heading level0 col0" colspan="2">N</th>
#       <th id="T_3b1dd_level0_col2" class="col_heading level0 col2" colspan="2">Y</th>
#       <th id="T_3b1dd_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Gender</th>
#       <th id="T_3b1dd_level1_col0" class="col_heading level1 col0" >Female</th>
#       <th id="T_3b1dd_level1_col1" class="col_heading level1 col1" >Male</th>
#       <th id="T_3b1dd_level1_col2" class="col_heading level1 col2" >Female</th>
#       <th id="T_3b1dd_level1_col3" class="col_heading level1 col3" >Male</th>
#       <th id="T_3b1dd_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dependents</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b1dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b1dd_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_3b1dd_row0_col1" class="data row0 col1" >86</td>
#       <td id="T_3b1dd_row0_col2" class="data row0 col2" >56</td>
#       <td id="T_3b1dd_row0_col3" class="data row0 col3" >191</td>
#       <td id="T_3b1dd_row0_col4" class="data row0 col4" >360</td>
#     </tr>
#     <tr>
#       <th id="T_3b1dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b1dd_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_3b1dd_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_3b1dd_row1_col2" class="data row1 col2" >13</td>
#       <td id="T_3b1dd_row1_col3" class="data row1 col3" >53</td>
#       <td id="T_3b1dd_row1_col4" class="data row1 col4" >102</td>
#     </tr>
#     <tr>
#       <th id="T_3b1dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3b1dd_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_3b1dd_row2_col1" class="data row2 col1" >23</td>
#       <td id="T_3b1dd_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_3b1dd_row2_col3" class="data row2 col3" >71</td>
#       <td id="T_3b1dd_row2_col4" class="data row2 col4" >101</td>
#     </tr>
#     <tr>
#       <th id="T_3b1dd_level0_row3" class="row_heading level0 row3" >3+</th>
#       <td id="T_3b1dd_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_3b1dd_row3_col1" class="data row3 col1" >16</td>
#       <td id="T_3b1dd_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_3b1dd_row3_col3" class="data row3 col3" >32</td>
#       <td id="T_3b1dd_row3_col4" class="data row3 col4" >51</td>
#     </tr>
#     <tr>
#       <th id="T_3b1dd_level0_row4" class="row_heading level0 row4" >All</th>
#       <td id="T_3b1dd_row4_col0" class="data row4 col0" >37</td>
#       <td id="T_3b1dd_row4_col1" class="data row4 col1" >155</td>
#       <td id="T_3b1dd_row4_col2" class="data row4 col2" >75</td>
#       <td id="T_3b1dd_row4_col3" class="data row4 col3" >347</td>
#       <td id="T_3b1dd_row4_col4" class="data row4 col4" >614</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab([df['Dependents'],df['Gender']],[df.Loan_Status],margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ee6ef_row0_col0, #T_ee6ef_row0_col1, #T_ee6ef_row0_col2, #T_ee6ef_row3_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_ee6ef_row1_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_ee6ef_row1_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_ee6ef_row1_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_ee6ef_row2_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_ee6ef_row2_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_ee6ef_row2_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_ee6ef_row3_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_ee6ef_row3_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_ee6ef_row4_col0, #T_ee6ef_row6_col0, #T_ee6ef_row6_col1, #T_ee6ef_row6_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ee6ef_row4_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_ee6ef_row4_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_ee6ef_row5_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_ee6ef_row5_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_ee6ef_row5_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_ee6ef_row7_col0, #T_ee6ef_row7_col1, #T_ee6ef_row7_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_ee6ef_row8_col0, #T_ee6ef_row8_col1, #T_ee6ef_row8_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ee6ef">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Loan_Status</th>
#       <th id="T_ee6ef_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_ee6ef_level0_col1" class="col_heading level0 col1" >Y</th>
#       <th id="T_ee6ef_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dependents</th>
#       <th class="index_name level1" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee6ef_level0_row0" class="row_heading level0 row0" rowspan="2">0</th>
#       <th id="T_ee6ef_level1_row0" class="row_heading level1 row0" >Female</th>
#       <td id="T_ee6ef_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_ee6ef_row0_col1" class="data row0 col1" >56</td>
#       <td id="T_ee6ef_row0_col2" class="data row0 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_ee6ef_level1_row1" class="row_heading level1 row1" >Male</th>
#       <td id="T_ee6ef_row1_col0" class="data row1 col0" >86</td>
#       <td id="T_ee6ef_row1_col1" class="data row1 col1" >191</td>
#       <td id="T_ee6ef_row1_col2" class="data row1 col2" >277</td>
#     </tr>
#     <tr>
#       <th id="T_ee6ef_level0_row2" class="row_heading level0 row2" rowspan="2">1</th>
#       <th id="T_ee6ef_level1_row2" class="row_heading level1 row2" >Female</th>
#       <td id="T_ee6ef_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_ee6ef_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_ee6ef_row2_col2" class="data row2 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_ee6ef_level1_row3" class="row_heading level1 row3" >Male</th>
#       <td id="T_ee6ef_row3_col0" class="data row3 col0" >30</td>
#       <td id="T_ee6ef_row3_col1" class="data row3 col1" >53</td>
#       <td id="T_ee6ef_row3_col2" class="data row3 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_ee6ef_level0_row4" class="row_heading level0 row4" rowspan="2">2</th>
#       <th id="T_ee6ef_level1_row4" class="row_heading level1 row4" >Female</th>
#       <td id="T_ee6ef_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_ee6ef_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_ee6ef_row4_col2" class="data row4 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_ee6ef_level1_row5" class="row_heading level1 row5" >Male</th>
#       <td id="T_ee6ef_row5_col0" class="data row5 col0" >23</td>
#       <td id="T_ee6ef_row5_col1" class="data row5 col1" >71</td>
#       <td id="T_ee6ef_row5_col2" class="data row5 col2" >94</td>
#     </tr>
#     <tr>
#       <th id="T_ee6ef_level0_row6" class="row_heading level0 row6" rowspan="2">3+</th>
#       <th id="T_ee6ef_level1_row6" class="row_heading level1 row6" >Female</th>
#       <td id="T_ee6ef_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_ee6ef_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_ee6ef_row6_col2" class="data row6 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ee6ef_level1_row7" class="row_heading level1 row7" >Male</th>
#       <td id="T_ee6ef_row7_col0" class="data row7 col0" >16</td>
#       <td id="T_ee6ef_row7_col1" class="data row7 col1" >32</td>
#       <td id="T_ee6ef_row7_col2" class="data row7 col2" >48</td>
#     </tr>
#     <tr>
#       <th id="T_ee6ef_level0_row8" class="row_heading level0 row8" >All</th>
#       <th id="T_ee6ef_level1_row8" class="row_heading level1 row8" ></th>
#       <td id="T_ee6ef_row8_col0" class="data row8 col0" >192</td>
#       <td id="T_ee6ef_row8_col1" class="data row8 col1" >422</td>
#       <td id="T_ee6ef_row8_col2" class="data row8 col2" >614</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Comment:
# 58.6% Applicants have no dependents on them.33% Applicants have either 1 or 2 dependents.
# It will interesting check whether with increase in number dependents their is increase in requirement loan amount.
# Female having zero dependents have more chances to get loan approval compare to Females with dependents.
# For male Maximum loan approval comes with 0 dependents followed by 2 dependents.

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# # Education Vs Loan status

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('prism')
f,ax=plt.subplots(1,2,figsize=(16,8))
df['Education'].value_counts().plot.pie(explode=[0,0.1],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Education', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot(x='Education',hue="Loan_Status",data=df,ax=ax[1])
ax[1].set_title('Education Vs Loan Status',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Education",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
 pd.crosstab([df['Education'],df['Gender']],[df.Loan_Status],margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_b8e0f_row0_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_b8e0f_row0_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_b8e0f_row0_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_b8e0f_row1_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_b8e0f_row1_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_b8e0f_row1_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_b8e0f_row2_col0, #T_b8e0f_row2_col1, #T_b8e0f_row2_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b8e0f_row3_col0 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_b8e0f_row3_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_b8e0f_row3_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_b8e0f_row4_col0, #T_b8e0f_row4_col1, #T_b8e0f_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b8e0f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Loan_Status</th>
#       <th id="T_b8e0f_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_b8e0f_level0_col1" class="col_heading level0 col1" >Y</th>
#       <th id="T_b8e0f_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="index_name level1" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8e0f_level0_row0" class="row_heading level0 row0" rowspan="2">Graduate</th>
#       <th id="T_b8e0f_level1_row0" class="row_heading level1 row0" >Female</th>
#       <td id="T_b8e0f_row0_col0" class="data row0 col0" >31</td>
#       <td id="T_b8e0f_row0_col1" class="data row0 col1" >61</td>
#       <td id="T_b8e0f_row0_col2" class="data row0 col2" >92</td>
#     </tr>
#     <tr>
#       <th id="T_b8e0f_level1_row1" class="row_heading level1 row1" >Male</th>
#       <td id="T_b8e0f_row1_col0" class="data row1 col0" >109</td>
#       <td id="T_b8e0f_row1_col1" class="data row1 col1" >279</td>
#       <td id="T_b8e0f_row1_col2" class="data row1 col2" >388</td>
#     </tr>
#     <tr>
#       <th id="T_b8e0f_level0_row2" class="row_heading level0 row2" rowspan="2">Not Graduate</th>
#       <th id="T_b8e0f_level1_row2" class="row_heading level1 row2" >Female</th>
#       <td id="T_b8e0f_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_b8e0f_row2_col1" class="data row2 col1" >14</td>
#       <td id="T_b8e0f_row2_col2" class="data row2 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_b8e0f_level1_row3" class="row_heading level1 row3" >Male</th>
#       <td id="T_b8e0f_row3_col0" class="data row3 col0" >46</td>
#       <td id="T_b8e0f_row3_col1" class="data row3 col1" >68</td>
#       <td id="T_b8e0f_row3_col2" class="data row3 col2" >114</td>
#     </tr>
#     <tr>
#       <th id="T_b8e0f_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_b8e0f_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_b8e0f_row4_col0" class="data row4 col0" >192</td>
#       <td id="T_b8e0f_row4_col1" class="data row4 col1" >422</td>
#       <td id="T_b8e0f_row4_col2" class="data row4 col2" >614</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Comment:
# Graduate applicants are more likely to get loan approval irrespective gender.

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# # Encoding categorical data

# %%
Category=['Gender','Married','Education','Self_Employed','Property_Area','Loan_Status']

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001002       1        0          0          0              0
# 1  LP001003       1        1          1          0              0
# 2  LP001005       1        1          0          0              1
# 3  LP001006       1        1          0          1              0
# 4  LP001008       1        0          0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            1
# 1             1.0              0            0
# 2             1.0              2            1
# 3             1.0              2            1
# 4             1.0              2            1

# %% [markdown]
# # Feature selection and Engineering
#
# 1. Outliers Detection and Removal

# %%
Numerical =['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']

# %%
plt.figure(figsize=(12,8),facecolor='white')
plotnumber=1

for column in Numerical:
    if plotnumber<=4:
        ax=plt.subplot(2,2,plotnumber)
        sns.boxplot(df[column],color='c')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
# Droping unnecessary columns
df.drop(["Loan_ID"], axis=1, inplace=True)

# %%
df['Dependents'] = df.Dependents.map({'0':0,'1':1,'2':2,'3+':3})

# %%
df['Dependents'] =pd.to_numeric(df['Dependents'])

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (614, 12)
# Shape of the dataframe after removing outliers:  (577, 12)
# Percentage of data loss post outlier removal:  6.026058631921824

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((614-577)/614)*100,'%')
# Out:
# Percentage Data Loss : 6.026058631921824 %

# %% [markdown]
# We are losing 6.02 % of data and which Acceptable.

# %% [markdown]
# # 2. Skewness of features

# %%
plt.figure(figsize=(22,5),facecolor='white')
plotnum=1
for col in Numerical:
    if plotnum<=4:
        plt.subplot(1,4,plotnum)
        sns.distplot(df[col],color='r')
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
df.skew()
# Out:
# Gender              -1.622920
# Married             -0.630211
# Dependents           1.052106
# Education            1.306588
# Self_Employed        2.252848
# ApplicantIncome      2.148522
# CoapplicantIncome    1.350517
# LoanAmount           1.151525
# Loan_Amount_Term    -2.098806
# Credit_History      -1.976043
# Property_Area       -0.055332
# Loan_Status         -0.822635
# dtype: float64

# %% [markdown]
# Comment :
# Out of all above feature 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount' are skewed which are numerical feature.
# Other features are categorical in nature so skewness is nothing to do with these remaining feature.We will ignore them.
# We will yeo-johnson transformation method.

# %%
# Removing skewness using yeo-johnson  method to get better prediction
skew = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
df[skew] = scaler.fit_transform(df[skew].values)
df[skew].head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount
# 0         0.681780          -1.122446    0.000771
# 1         0.234783           0.744117    0.000771
# 2        -0.527201          -1.122446   -1.437336
# 3        -0.791972           0.895786   -0.153545
# 4         0.728848          -1.122446    0.238260

# %% [markdown]
# # Checking skewness after using yeo-johnson ethod

# %%
df.skew()
# Out:
# Gender              -1.622920
# Married             -0.630211
# Dependents           1.052106
# Education            1.306588
# Self_Employed        2.252848
# ApplicantIncome      0.027981
# CoapplicantIncome   -0.191876
# LoanAmount           0.048425
# Loan_Amount_Term    -2.098806
# Credit_History      -1.976043
# Property_Area       -0.055332
# Loan_Status         -0.822635
# dtype: float64

# %% [markdown]
# For Numerical variable skewness is within permissible limit.
#
# So Yes To Go Forward !!!

# %% [markdown]
# # 3. Corrleation

# %%
df.corr()
# Out:
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.378997    0.188162   0.045696      -0.006207
# Married            0.378997  1.000000    0.329900   0.024817      -0.015779
# Dependents         0.188162  0.329900    1.000000   0.069814       0.044543
# Education          0.045696  0.024817    0.069814   1.000000      -0.007139
# Self_Employed     -0.006207 -0.015779    0.044543  -0.007139       1.000000
# ApplicantIncome    0.058590 -0.024783    0.105994  -0.176074       0.212260
# CoapplicantIncome  0.234551  0.335820    0.004109   0.049739      -0.087338
# LoanAmount         0.172146  0.181878    0.131772  -0.128715       0.117218
# Loan_Amount_Term  -0.104983 -0.127348   -0.087389  -0.090523      -0.032914
# Credit_History     0.013172  0.019308   -0.020288  -0.075217      -0.016390
# Property_Area     -0.026340  0.010595    0.002327  -0.068596      -0.028253
# Loan_Status        0.017408  0.089026    0.017872  -0.092658      -0.026525
#
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Gender                    0.058590           0.234551    0.172146
# Married                  -0.024783           0.335820    0.181878
# Dependents                0.105994           0.004109    0.131772
# Education                -0.176074           0.049739   -0.128715
# Self_Employed             0.212260          -0.087338    0.117218
# ApplicantIncome           1.000000          -0.360946    0.432154
# CoapplicantIncome        -0.360946           1.000000    0.200081
# LoanAmount                0.432154           0.200081    1.000000
# Loan_Amount_Term         -0.069429           0.000951    0.049057
# Credit_History            0.028825           0.006564   -0.003626
# Property_Area            -0.011364          -0.074476   -0.098090
# Loan_Status              -0.002484           0.079344   -0.023609
#
#                    Loan_Amount_Term  Credit_History  Property_Area  \
# Gender                    -0.104983        0.013172      -0.026340
# Married                   -0.127348        0.019308       0.010595
# Dependents                -0.087389       -0.020288       0.002327
# Education                 -0.090523       -0.075217      -0.068596
# Self_Employed             -0.032914       -0.016390      -0.028253
# ApplicantIncome           -0.069429        0.028825      -0.011364
# CoapplicantIncome          0.000951        0.006564      -0.074476
# LoanAmount                 0.049057       -0.003626      -0.098090
# Loan_Amount_Term           1.000000        0.027392      -0.057004
# Credit_History             0.027392        1.000000      -0.008121
# Property_Area             -0.057004       -0.008121       1.000000
# Loan_Status               -0.020291        0.560936       0.026507
#
#                    Loan_Status
# Gender                0.017408
# Married               0.089026
# Dependents            0.017872
# Education            -0.092658
# Self_Employed        -0.026525
# ApplicantIncome      -0.002484
# CoapplicantIncome     0.079344
# LoanAmount           -0.023609
# Loan_Amount_Term     -0.020291
# Credit_History        0.560936
# Property_Area         0.026507
# Loan_Status           1.000000

# %%
plt.figure(figsize=(21,13))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df.corr()['Loan_Status'].drop(['Loan_Status']).sort_values(ascending=False).plot(kind='bar',color = 'purple')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Income',fontsize=15)
plt.title('Correlation of features with Target Variable Loan_Status',fontsize = 18)
plt.show()

# %% [markdown]
# Observation:
# Most of feature are poorly or moderately correlated with target variable expect Credit History.
#
# Maximum correlation of 0.561 exist between Credit History and Loan status.

# %% [markdown]
# # 4. Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
vif['Features']= df.columns
vif
# Out:
#           VIF           Features
# 0    6.119789             Gender
# 1    3.963538            Married
# 2    1.778377         Dependents
# 3    1.355469          Education
# 4    1.197219      Self_Employed
# 5    1.756726    ApplicantIncome
# 6    1.596438  CoapplicantIncome
# 7    1.548450         LoanAmount
# 8   10.415255   Loan_Amount_Term
# 9    9.483180     Credit_History
# 10   2.654799      Property_Area
# 11   4.818436        Loan_Status

# %% [markdown]
# All features VIF is within permissible limit of 10.
#
# So No Need to Worry About Multicollinearity.

# %% [markdown]
# # 5. Balanceing Imbalanced target feature

# %%
df.Loan_Status.value_counts()
# Out:
# 1    398
# 0    179
# Name: Loan_Status, dtype: int64

# %% [markdown]
# As Target variable data is Imbalanced in nature we will need to balance target variable.

# %% [markdown]
# # Balancing using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
# Splitting data in target and dependent feature
X = df.drop(['Loan_Status'], axis =1)
Y = df['Loan_Status']

# %%
# Oversampleing using SMOTE Techniques
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 1    398
# 0    398
# Name: Loan_Status, dtype: int64

# %% [markdown]
# We have successfully resolved the class imbalanced problem and now all the categories have same data ensuring that the ML model does not get biased towards one category.

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (557, 11)
# Training target vector size: (557,)
# Test feature matrix size: (239, 11)
# Test target vector size: (239,)

# %% [markdown]
# # Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(X_scale,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.8200836820083682 on Random_state 177

# %% [markdown]
# # Logistics Regression Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=78, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.799163179916318
#
#
# Confusion matrix of Logistics Regression :
#  [[ 69  41]
#  [  7 122]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.91      0.63      0.74       110
#            1       0.75      0.95      0.84       129
#
#     accuracy                           0.80       239
#    macro avg       0.83      0.79      0.79       239
# weighted avg       0.82      0.80      0.79       239

# %% [markdown]
# # Finding Optimal value of n_neighbors for KNN

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(25):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.4883581921595791
# RMSE value for k=  2 is: 0.5294664560040351
# RMSE value for k=  3 is: 0.5093272287453544
# RMSE value for k=  4 is: 0.5411903817407538
# RMSE value for k=  5 is: 0.49262341019056577
# RMSE value for k=  6 is: 0.5174769818825207
# RMSE value for k=  7 is: 0.4968520148758506
# RMSE value for k=  8 is: 0.5093272287453544
# RMSE value for k=  9 is: 0.4968520148758506
# RMSE value for k=  10 is: 0.5093272287453544
# RMSE value for k=  11 is: 0.47091116165974684
# RMSE value for k=  12 is: 0.49262341019056577
# RMSE value for k=  13 is: 0.4753329597178616
# RMSE value for k=  14 is: 0.47971400126799746
# RMSE value for k=  15 is: 0.4883581921595791
# RMSE value for k=  16 is: 0.49262341019056577
# RMSE value for k=  17 is: 0.49262341019056577
# RMSE value for k=  18 is: 0.4968520148758506
# RMSE value for k=  19 is: 0.513418276223035
# RMSE value for k=  20 is: 0.513418276223035
# RMSE value for k=  21 is: 0.50104493321917
# RMSE value for k=  22 is: 0.4968520148758506
# RMSE value for k=  23 is: 0.4968520148758506
# RMSE value for k=  24 is: 0.49262341019056577
# RMSE value for k=  25 is: 0.50104493321917

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(25), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %% [markdown]
# Comment-
# At k=3, we get the minimum RMSE value which approximately 0.44814821218396267, and shoots up on further increasing the k value. We can safely say that k=3 will give us the best result in this case

# %%
from sklearn.metrics import plot_roc_curve
model=[ SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]
        
for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    disp = plot_roc_curve(m,X_test,Y_test)   
    plt.legend(prop={'size':11}, loc='lower right')
    plt.show()
    print('============================================================================================================')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 from sklearn.metrics import plot_roc_curve
#       2 model=[ SVC(),
#       3         GaussianNB(),
#       4         DecisionTreeClassifier(),
#       5         KNeighborsClassifier(n_neighbors = 3),
#       6         RandomForestClassifier(),
#       7         ExtraTreesClassifier()]
#       9 for m in model:
#
# ImportError: cannot import name 'plot_roc_curve' from 'sklearn.metrics' (C:\Users\jagri\anaconda3\lib\site-packages\sklearn\metrics\__init__.py)

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, X_scale, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('============================================================================================================')
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.6875     0.6918239  0.74842767 0.76100629 0.81761006]
# Mean Score : 0.7412735849056604
# Std deviation : 0.04817611089216111
#
#
# ============================================================================================================
#
#
# Cross Validation Score SVC() :
#
# Score : [0.7        0.74213836 0.77358491 0.73584906 0.82389937]
# Mean Score : 0.7550943396226415
# Std deviation : 0.04159244605890131
#
#
# ============================================================================================================
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.69375    0.72955975 0.72955975 0.75471698 0.77987421]
# Mean Score : 0.7374921383647799
# Std deviation : 0.028747715800038643
#
#
# ============================================================================================================
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.68125    0.74213836 0.75471698 0.77987421 0.78616352]
# Mean Score : 0.7488286163522013
# Std deviation : 0.03742733225273985
#
#
# ============================================================================================================
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=3) :
#
# Score : [0.7125     0.72327044 0.73584906 0.72955975 0.79874214]
# Mean Score : 0.7399842767295597
# Std deviation : 0.030374314599375403
#
#
# ============================================================================================================
#
#
# Cross Validation Score RandomForestClassifier() :
#
# Score : [0.78125    0.79874214 0.79245283 0.8427673  0.89308176]
# Mean Score : 0.8216588050314467
# Std deviation : 0.04137110372194041
#
#
# ============================================================================================================
#
#
# Cross Validation Score ExtraTreesClassifier() :
#
# Score : [0.75       0.79874214 0.81132075 0.86792453 0.86792453]
# Mean Score : 0.8191823899371069
# Std deviation : 0.04476025999662412
#
#
# ============================================================================================================

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {  'bootstrap': [True], 'max_depth': [5, 10,20,40,50,60], 
              'max_features': ['auto', 'log2'], 
              'criterion':['gini','entropy'],
              'n_estimators': [5, 10, 15 ,25,50,60,70]}

# %%
GCV = GridSearchCV(RandomForestClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# [CV 1/5; 1/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5
# [CV 1/5; 1/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=0.732 total time=   0.0s
# [CV 2/5; 1/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5
# [CV 2/5; 1/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=0.768 total time=   0.0s
# [CV 3/5; 1/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5
# [CV 3/5; 1/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=0.793 total time=   0.0s
# [CV 4/5; 1/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5
# [CV 4/5; 1/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=0.685 total time=   0.0s
# [CV 5/5; 1/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5
# [CV 5/5; 1/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=0.649 total time=   0.0s
# [CV 1/5; 2/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10
# [CV 1/5; 2/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10;, score=0.759 total time=   0.0s
# [CV 2/5; 2/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10
# [CV 2/5; 2/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10;, score=0.723 total time=   0.0s
# [CV 3/5; 2/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10
# [CV 3/5; 2/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10;, score=0.739 total time=   0.0s
# [CV 4/5; 2/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10
# [CV 4/5; 2/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10;, score=0.730 total time=   0.0s
# [CV 5/5; 2/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10
# [CV 5/5; 2/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10;, score=0.712 total time=   0.0s
# [CV 1/5; 3/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15
# [CV 1/5; 3/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15;, score=0.696 total time=   0.0s
# [CV 2/5; 3/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15
# [CV 2/5; 3/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15;, score=0.768 total time=   0.0s
# [CV 3/5; 3/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15
# [CV 3/5; 3/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15;, score=0.757 total time=   0.0s
# [CV 4/5; 3/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15
# [CV 4/5; 3/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15;, score=0.721 total time=   0.0s
# [CV 5/5; 3/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15
# [CV 5/5; 3/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15;, score=0.739 total time=   0.0s
# [CV 1/5; 4/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25
# [CV 1/5; 4/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25;, score=0.741 total time=   0.0s
# [CV 2/5; 4/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25
# [CV 2/5; 4/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25;, score=0.777 total time=   0.0s
# [CV 3/5; 4/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25
# [CV 3/5; 4/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25;, score=0.793 total time=   0.0s
# [CV 4/5; 4/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25
# [CV 4/5; 4/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25;, score=0.703 total time=   0.0s
# [CV 5/5; 4/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25
# [CV 5/5; 4/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25;, score=0.739 total time=   0.0s
# [CV 1/5; 5/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50
# [CV 1/5; 5/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50;, score=0.741 total time=   0.1s
# [CV 2/5; 5/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50
# [CV 2/5; 5/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50;, score=0.750 total time=   0.1s
# [CV 3/5; 5/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50
# [CV 3/5; 5/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50;, score=0.766 total time=   0.0s
# [CV 4/5; 5/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50
# [CV 4/5; 5/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50;, score=0.721 total time=   0.0s
# [CV 5/5; 5/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50
# [CV 5/5; 5/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50;, score=0.730 total time=   0.0s
# [CV 1/5; 6/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60
# [CV 1/5; 6/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60;, score=0.741 total time=   0.0s
# [CV 2/5; 6/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60
# [CV 2/5; 6/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60;, score=0.786 total time=   0.1s
# [CV 3/5; 6/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60
# [CV 3/5; 6/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60;, score=0.748 total time=   0.1s
# [CV 4/5; 6/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60
# [CV 4/5; 6/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60;, score=0.730 total time=   0.1s
# [CV 5/5; 6/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60
# [CV 5/5; 6/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60;, score=0.739 total time=   0.1s
# [CV 1/5; 7/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70
# [CV 1/5; 7/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70;, score=0.768 total time=   0.1s
# [CV 2/5; 7/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70
# [CV 2/5; 7/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70;, score=0.777 total time=   0.1s
# [CV 3/5; 7/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70
# [CV 3/5; 7/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70;, score=0.748 total time=   0.1s
# [CV 4/5; 7/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70
# [CV 4/5; 7/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70;, score=0.703 total time=   0.0s
# [CV 5/5; 7/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70
# [CV 5/5; 7/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70;, score=0.739 total time=   0.1s
# [CV 1/5; 8/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5
# [CV 1/5; 8/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.714 total time=   0.0s
# [CV 2/5; 8/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5
# [CV 2/5; 8/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.723 total time=   0.0s
# [CV 3/5; 8/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5
# [CV 3/5; 8/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.658 total time=   0.0s
# [CV 4/5; 8/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5
# [CV 4/5; 8/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.685 total time=   0.0s
# [CV 5/5; 8/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5
# [CV 5/5; 8/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.694 total time=   0.0s
# [CV 1/5; 9/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10
# [CV 1/5; 9/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10;, score=0.786 total time=   0.0s
# [CV 2/5; 9/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10
# [CV 2/5; 9/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10;, score=0.768 total time=   0.0s
# [CV 3/5; 9/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10
# [CV 3/5; 9/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10;, score=0.775 total time=   0.0s
# [CV 4/5; 9/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10
# [CV 4/5; 9/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10;, score=0.721 total time=   0.0s
# [CV 5/5; 9/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10
# [CV 5/5; 9/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10;, score=0.730 total time=   0.0s
# [CV 1/5; 10/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15
# [CV 1/5; 10/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15;, score=0.723 total time=   0.0s
# [CV 2/5; 10/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15
# [CV 2/5; 10/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15;, score=0.732 total time=   0.0s
# [CV 3/5; 10/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15
# [CV 3/5; 10/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15;, score=0.739 total time=   0.0s
# [CV 4/5; 10/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15
# [CV 4/5; 10/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15;, score=0.676 total time=   0.0s
# [CV 5/5; 10/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15
# [CV 5/5; 10/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15;, score=0.712 total time=   0.0s
# [CV 1/5; 11/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25
# [CV 1/5; 11/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25;, score=0.768 total time=   0.0s
# [CV 2/5; 11/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25
# [CV 2/5; 11/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25;, score=0.750 total time=   0.0s
# [CV 3/5; 11/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25
# [CV 3/5; 11/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25;, score=0.766 total time=   0.0s
# [CV 4/5; 11/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25
# [CV 4/5; 11/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25;, score=0.667 total time=   0.0s
# [CV 5/5; 11/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25
# [CV 5/5; 11/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25;, score=0.712 total time=   0.0s
# [CV 1/5; 12/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=50
# [CV 1/5; 12/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=50;, score=0.723 total time=   0.0s
# [CV 2/5; 12/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=50
# [CV 2/5; 12/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=50;, score=0.750 total time=   0.0s
# [CV 3/5; 12/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=50
# [CV 3/5; 12/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=50;, score=0.775 total time=   0.0s
# [CV 4/5; 12/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=50
# [CV 4/5; 12/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=50;, score=0.703 total time=   0.0s
# [CV 5/5; 12/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=50
# [CV 5/5; 12/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=50;, score=0.721 total time=   0.0s
# [CV 1/5; 13/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=60
# [CV 1/5; 13/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=60;, score=0.768 total time=   0.0s
# [CV 2/5; 13/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=60
# [CV 2/5; 13/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=60;, score=0.768 total time=   0.0s
# [CV 3/5; 13/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=60
# [CV 3/5; 13/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=60;, score=0.775 total time=   0.0s
# [CV 4/5; 13/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=60
# [CV 4/5; 13/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=60;, score=0.721 total time=   0.0s
# [CV 5/5; 13/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=60
# [CV 5/5; 13/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=60;, score=0.739 total time=   0.0s
# [CV 1/5; 14/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=70
# [CV 1/5; 14/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=70;, score=0.750 total time=   0.1s
# [CV 2/5; 14/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=70
# [CV 2/5; 14/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=70;, score=0.750 total time=   0.1s
# [CV 3/5; 14/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=70
# [CV 3/5; 14/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=70;, score=0.766 total time=   0.1s
# [CV 4/5; 14/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=70
# [CV 4/5; 14/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=70;, score=0.703 total time=   0.1s
# [CV 5/5; 14/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=70
# [CV 5/5; 14/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=70;, score=0.730 total time=   0.1s
# [CV 1/5; 15/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=5
# [CV 1/5; 15/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=5;, score=0.821 total time=   0.0s
# [CV 2/5; 15/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=5
# [CV 2/5; 15/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=5;, score=0.723 total time=   0.0s
# [CV 3/5; 15/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=5
# [CV 3/5; 15/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=5;, score=0.739 total time=   0.0s
# [CV 4/5; 15/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=5
# [CV 4/5; 15/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=5;, score=0.721 total time=   0.0s
# [CV 5/5; 15/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=5
# [CV 5/5; 15/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=5;, score=0.721 total time=   0.0s
# [CV 1/5; 16/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=10
# [CV 1/5; 16/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=10;, score=0.768 total time=   0.0s
# [CV 2/5; 16/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=10
# [CV 2/5; 16/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=10;, score=0.723 total time=   0.0s
# [CV 3/5; 16/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=10
# [CV 3/5; 16/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=10;, score=0.829 total time=   0.0s
# [CV 4/5; 16/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=10
# [CV 4/5; 16/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=10;, score=0.712 total time=   0.0s
# [CV 5/5; 16/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=10
# [CV 5/5; 16/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=10;, score=0.703 total time=   0.0s
# [CV 1/5; 17/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=15
# [CV 1/5; 17/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=15;, score=0.804 total time=   0.0s
# [CV 2/5; 17/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=15
# [CV 2/5; 17/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=15;, score=0.777 total time=   0.0s
# [CV 3/5; 17/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=15
# [CV 3/5; 17/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=15;, score=0.784 total time=   0.0s
# [CV 4/5; 17/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=15
# [CV 4/5; 17/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=15;, score=0.739 total time=   0.0s
# [CV 5/5; 17/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=15
# [CV 5/5; 17/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=15;, score=0.730 total time=   0.0s
# [CV 1/5; 18/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=25
# [CV 1/5; 18/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=25;, score=0.786 total time=   0.0s
# [CV 2/5; 18/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=25
# [CV 2/5; 18/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=25;, score=0.777 total time=   0.0s
# [CV 3/5; 18/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=25
# [CV 3/5; 18/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=25;, score=0.802 total time=   0.0s
# [CV 4/5; 18/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=25
# [CV 4/5; 18/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=25;, score=0.739 total time=   0.0s
# [CV 5/5; 18/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=25
# [CV 5/5; 18/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=25;, score=0.730 total time=   0.0s
# [CV 1/5; 19/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=50
# [CV 1/5; 19/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=50;, score=0.812 total time=   0.0s
# [CV 2/5; 19/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=50
# [CV 2/5; 19/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=50;, score=0.750 total time=   0.0s
# [CV 3/5; 19/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=50
# [CV 3/5; 19/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=50;, score=0.838 total time=   0.0s
# [CV 4/5; 19/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=50
# [CV 4/5; 19/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=50;, score=0.757 total time=   0.0s
# [CV 5/5; 19/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=50
# [CV 5/5; 19/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=50;, score=0.721 total time=   0.0s
# [CV 1/5; 20/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=60
# [CV 1/5; 20/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=60;, score=0.786 total time=   0.0s
# [CV 2/5; 20/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=60
# [CV 2/5; 20/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=60;, score=0.750 total time=   0.0s
# [CV 3/5; 20/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=60
# [CV 3/5; 20/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=60;, score=0.784 total time=   0.0s
# [CV 4/5; 20/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=60
# [CV 4/5; 20/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=60;, score=0.775 total time=   0.1s
# [CV 5/5; 20/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=60
# [CV 5/5; 20/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=60;, score=0.730 total time=   0.1s
# [CV 1/5; 21/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=70
# [CV 1/5; 21/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=70;, score=0.786 total time=   0.1s
# [CV 2/5; 21/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=70
# [CV 2/5; 21/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=70;, score=0.759 total time=   0.1s
# [CV 3/5; 21/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=70
# [CV 3/5; 21/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=70;, score=0.802 total time=   0.1s
# [CV 4/5; 21/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=70
# [CV 4/5; 21/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=70;, score=0.748 total time=   0.1s
# [CV 5/5; 21/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=70
# [CV 5/5; 21/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=auto, n_estimators=70;, score=0.721 total time=   0.1s
# [CV 1/5; 22/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=5
# [CV 1/5; 22/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=5;, score=0.741 total time=   0.0s
# [CV 2/5; 22/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=5
# [CV 2/5; 22/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=5;, score=0.732 total time=   0.0s
# [CV 3/5; 22/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=5
# [CV 3/5; 22/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=5;, score=0.847 total time=   0.0s
# [CV 4/5; 22/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=5
# [CV 4/5; 22/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=5;, score=0.694 total time=   0.0s
# [CV 5/5; 22/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=5
# [CV 5/5; 22/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=5;, score=0.685 total time=   0.0s
# [CV 1/5; 23/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=10
# [CV 1/5; 23/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=10;, score=0.786 total time=   0.0s
# [CV 2/5; 23/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=10
# [CV 2/5; 23/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=10;, score=0.741 total time=   0.0s
# [CV 3/5; 23/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=10
# [CV 3/5; 23/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=10;, score=0.730 total time=   0.0s
# [CV 4/5; 23/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=10
# [CV 4/5; 23/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=10;, score=0.775 total time=   0.0s
# [CV 5/5; 23/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=10
# [CV 5/5; 23/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=10;, score=0.703 total time=   0.0s
# [CV 1/5; 24/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=15
# [CV 1/5; 24/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=15;, score=0.804 total time=   0.0s
# [CV 2/5; 24/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=15
# [CV 2/5; 24/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=15;, score=0.732 total time=   0.0s
# [CV 3/5; 24/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=15
# [CV 3/5; 24/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=15;, score=0.748 total time=   0.0s
# [CV 4/5; 24/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=15
# [CV 4/5; 24/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=15;, score=0.721 total time=   0.0s
# [CV 5/5; 24/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=15
# [CV 5/5; 24/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=15;, score=0.694 total time=   0.0s
# [CV 1/5; 25/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=25
# [CV 1/5; 25/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=25;, score=0.821 total time=   0.0s
# [CV 2/5; 25/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=25
# [CV 2/5; 25/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=25;, score=0.812 total time=   0.0s
# [CV 3/5; 25/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=25
# [CV 3/5; 25/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=25;, score=0.775 total time=   0.0s
# [CV 4/5; 25/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=25
# [CV 4/5; 25/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=25;, score=0.739 total time=   0.0s
# [CV 5/5; 25/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=25
# [CV 5/5; 25/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=25;, score=0.766 total time=   0.0s
# [CV 1/5; 26/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=50
# [CV 1/5; 26/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=50;, score=0.812 total time=   0.1s
# [CV 2/5; 26/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=50
# [CV 2/5; 26/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=50;, score=0.777 total time=   0.0s
# [CV 3/5; 26/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=50
# [CV 3/5; 26/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=50;, score=0.793 total time=   0.0s
# [CV 4/5; 26/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=50
# [CV 4/5; 26/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=50;, score=0.766 total time=   0.1s
# [CV 5/5; 26/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=50
# [CV 5/5; 26/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=50;, score=0.766 total time=   0.0s
# [CV 1/5; 27/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60
# [CV 1/5; 27/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60;, score=0.804 total time=   0.0s
# [CV 2/5; 27/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60
# [CV 2/5; 27/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60;, score=0.759 total time=   0.1s
# [CV 3/5; 27/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60
# [CV 3/5; 27/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60;, score=0.793 total time=   0.1s
# [CV 4/5; 27/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60
# [CV 4/5; 27/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60;, score=0.766 total time=   0.1s
# [CV 5/5; 27/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60
# [CV 5/5; 27/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60;, score=0.730 total time=   0.1s
# [CV 1/5; 28/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70
# [CV 1/5; 28/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70;, score=0.759 total time=   0.1s
# [CV 2/5; 28/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70
# [CV 2/5; 28/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70;, score=0.741 total time=   0.1s
# [CV 3/5; 28/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70
# [CV 3/5; 28/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70;, score=0.811 total time=   0.1s
# [CV 4/5; 28/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70
# [CV 4/5; 28/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70;, score=0.775 total time=   0.1s
# [CV 5/5; 28/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70
# [CV 5/5; 28/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70;, score=0.721 total time=   0.1s
# [CV 1/5; 29/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5
# [CV 1/5; 29/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5;, score=0.741 total time=   0.0s
# [CV 2/5; 29/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5
# [CV 2/5; 29/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5;, score=0.812 total time=   0.0s
# [CV 3/5; 29/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5
# [CV 3/5; 29/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5;, score=0.757 total time=   0.0s
# [CV 4/5; 29/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5
# [CV 4/5; 29/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5;, score=0.721 total time=   0.0s
# [CV 5/5; 29/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5
# [CV 5/5; 29/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5;, score=0.712 total time=   0.0s
# [CV 1/5; 30/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10
# [CV 1/5; 30/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10;, score=0.786 total time=   0.0s
# [CV 2/5; 30/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10
# [CV 2/5; 30/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10;, score=0.741 total time=   0.0s
# [CV 3/5; 30/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10
# [CV 3/5; 30/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10;, score=0.739 total time=   0.0s
# [CV 4/5; 30/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10
# [CV 4/5; 30/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10;, score=0.748 total time=   0.0s
# [CV 5/5; 30/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10
# [CV 5/5; 30/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10;, score=0.748 total time=   0.0s
# [CV 1/5; 31/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15
# [CV 1/5; 31/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15;, score=0.830 total time=   0.0s
# [CV 2/5; 31/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15
# [CV 2/5; 31/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15;, score=0.804 total time=   0.0s
# [CV 3/5; 31/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15
# [CV 3/5; 31/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15;, score=0.811 total time=   0.0s
# [CV 4/5; 31/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15
# [CV 4/5; 31/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15;, score=0.730 total time=   0.0s
# [CV 5/5; 31/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15
# [CV 5/5; 31/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15;, score=0.748 total time=   0.0s
# [CV 1/5; 32/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25
# [CV 1/5; 32/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25;, score=0.821 total time=   0.0s
# [CV 2/5; 32/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25
# [CV 2/5; 32/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25;, score=0.768 total time=   0.0s
# [CV 3/5; 32/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25
# [CV 3/5; 32/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25;, score=0.775 total time=   0.0s
# [CV 4/5; 32/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25
# [CV 4/5; 32/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25;, score=0.766 total time=   0.0s
# [CV 5/5; 32/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25
# [CV 5/5; 32/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25;, score=0.730 total time=   0.0s
# [CV 1/5; 33/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50
# [CV 1/5; 33/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50;, score=0.812 total time=   0.0s
# [CV 2/5; 33/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50
# [CV 2/5; 33/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50;, score=0.777 total time=   0.0s
# [CV 3/5; 33/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50
# [CV 3/5; 33/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50;, score=0.820 total time=   0.0s
# [CV 4/5; 33/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50
# [CV 4/5; 33/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50;, score=0.748 total time=   0.0s
# [CV 5/5; 33/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50
# [CV 5/5; 33/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50;, score=0.712 total time=   0.0s
# [CV 1/5; 34/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60
# [CV 1/5; 34/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60;, score=0.804 total time=   0.1s
# [CV 2/5; 34/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60
# [CV 2/5; 34/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60;, score=0.750 total time=   0.1s
# [CV 3/5; 34/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60
# [CV 3/5; 34/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60;, score=0.793 total time=   0.1s
# [CV 4/5; 34/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60
# [CV 4/5; 34/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60;, score=0.775 total time=   0.1s
# [CV 5/5; 34/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60
# [CV 5/5; 34/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60;, score=0.730 total time=   0.0s
# [CV 1/5; 35/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70
# [CV 1/5; 35/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70;, score=0.830 total time=   0.1s
# [CV 2/5; 35/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70
# [CV 2/5; 35/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70;, score=0.768 total time=   0.1s
# [CV 3/5; 35/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70
# [CV 3/5; 35/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70;, score=0.802 total time=   0.1s
# [CV 4/5; 35/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70
# [CV 4/5; 35/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70;, score=0.739 total time=   0.1s
# [CV 5/5; 35/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70
# [CV 5/5; 35/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70;, score=0.748 total time=   0.1s
# [CV 1/5; 36/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5
# [CV 1/5; 36/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5;, score=0.795 total time=   0.0s
# [CV 2/5; 36/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5
# [CV 2/5; 36/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5;, score=0.768 total time=   0.0s
# [CV 3/5; 36/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5
# [CV 3/5; 36/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5;, score=0.793 total time=   0.0s
# [CV 4/5; 36/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5
# [CV 4/5; 36/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5;, score=0.784 total time=   0.0s
# [CV 5/5; 36/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5
# [CV 5/5; 36/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5;, score=0.694 total time=   0.0s
# [CV 1/5; 37/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10
# [CV 1/5; 37/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10;, score=0.804 total time=   0.0s
# [CV 2/5; 37/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10
# [CV 2/5; 37/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10;, score=0.723 total time=   0.0s
# [CV 3/5; 37/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10
# [CV 3/5; 37/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10;, score=0.802 total time=   0.0s
# [CV 4/5; 37/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10
# [CV 4/5; 37/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10;, score=0.775 total time=   0.0s
# [CV 5/5; 37/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10
# [CV 5/5; 37/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10;, score=0.739 total time=   0.0s
# [CV 1/5; 38/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15
# [CV 1/5; 38/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15;, score=0.804 total time=   0.0s
# [CV 2/5; 38/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15
# [CV 2/5; 38/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15;, score=0.786 total time=   0.0s
# [CV 3/5; 38/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15
# [CV 3/5; 38/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15;, score=0.820 total time=   0.0s
# [CV 4/5; 38/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15
# [CV 4/5; 38/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15;, score=0.748 total time=   0.0s
# [CV 5/5; 38/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15
# [CV 5/5; 38/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15;, score=0.712 total time=   0.0s
# [CV 1/5; 39/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25
# [CV 1/5; 39/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25;, score=0.795 total time=   0.0s
# [CV 2/5; 39/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25
# [CV 2/5; 39/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25;, score=0.795 total time=   0.0s
# [CV 3/5; 39/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25
# [CV 3/5; 39/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25;, score=0.811 total time=   0.0s
# [CV 4/5; 39/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25
# [CV 4/5; 39/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25;, score=0.730 total time=   0.0s
# [CV 5/5; 39/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25
# [CV 5/5; 39/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25;, score=0.739 total time=   0.0s
# [CV 1/5; 40/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50
# [CV 1/5; 40/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50;, score=0.839 total time=   0.0s
# [CV 2/5; 40/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50
# [CV 2/5; 40/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50;, score=0.759 total time=   0.1s
# [CV 3/5; 40/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50
# [CV 3/5; 40/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50;, score=0.811 total time=   0.0s
# [CV 4/5; 40/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50
# [CV 4/5; 40/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50;, score=0.766 total time=   0.0s
# [CV 5/5; 40/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50
# [CV 5/5; 40/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50;, score=0.739 total time=   0.0s
# [CV 1/5; 41/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=60
# [CV 1/5; 41/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=60;, score=0.821 total time=   0.1s
# [CV 2/5; 41/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=60
# ...
# [CV 3/5; 156/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10
# [CV 3/5; 156/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10;, score=0.784 total time=   0.0s
# [CV 4/5; 156/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10
# [CV 4/5; 156/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10;, score=0.730 total time=   0.0s
# [CV 5/5; 156/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10
# [CV 5/5; 156/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10;, score=0.685 total time=   0.0s
# [CV 1/5; 157/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15
# [CV 1/5; 157/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15;, score=0.830 total time=   0.0s
# [CV 2/5; 157/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15
# [CV 2/5; 157/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15;, score=0.750 total time=   0.0s
# [CV 3/5; 157/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15
# [CV 3/5; 157/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15;, score=0.820 total time=   0.0s
# [CV 4/5; 157/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15
# [CV 4/5; 157/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15;, score=0.775 total time=   0.0s
# [CV 5/5; 157/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15
# [CV 5/5; 157/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15;, score=0.685 total time=   0.0s
# [CV 1/5; 158/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25
# [CV 1/5; 158/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25;, score=0.830 total time=   0.0s
# [CV 2/5; 158/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25
# [CV 2/5; 158/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25;, score=0.786 total time=   0.0s
# [CV 3/5; 158/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25
# [CV 3/5; 158/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25;, score=0.829 total time=   0.0s
# [CV 4/5; 158/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25
# [CV 4/5; 158/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25;, score=0.739 total time=   0.0s
# [CV 5/5; 158/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25
# [CV 5/5; 158/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25;, score=0.802 total time=   0.0s
# [CV 1/5; 159/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50
# [CV 1/5; 159/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50;, score=0.821 total time=   0.0s
# [CV 2/5; 159/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50
# [CV 2/5; 159/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50;, score=0.759 total time=   0.1s
# [CV 3/5; 159/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50
# [CV 3/5; 159/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50;, score=0.820 total time=   0.0s
# [CV 4/5; 159/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50
# [CV 4/5; 159/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50;, score=0.748 total time=   0.0s
# [CV 5/5; 159/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50
# [CV 5/5; 159/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50;, score=0.739 total time=   0.1s
# [CV 1/5; 160/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60
# [CV 1/5; 160/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60;, score=0.804 total time=   0.1s
# [CV 2/5; 160/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60
# [CV 2/5; 160/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60;, score=0.759 total time=   0.1s
# [CV 3/5; 160/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60
# [CV 3/5; 160/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60;, score=0.802 total time=   0.1s
# [CV 4/5; 160/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60
# [CV 4/5; 160/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60;, score=0.766 total time=   0.1s
# [CV 5/5; 160/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60
# [CV 5/5; 160/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60;, score=0.748 total time=   0.1s
# [CV 1/5; 161/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70
# [CV 1/5; 161/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70;, score=0.821 total time=   0.1s
# [CV 2/5; 161/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70
# [CV 2/5; 161/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70;, score=0.786 total time=   0.1s
# [CV 3/5; 161/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70
# [CV 3/5; 161/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70;, score=0.802 total time=   0.1s
# [CV 4/5; 161/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70
# [CV 4/5; 161/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70;, score=0.766 total time=   0.1s
# [CV 5/5; 161/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70
# [CV 5/5; 161/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70;, score=0.775 total time=   0.1s
# [CV 1/5; 162/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5
# [CV 1/5; 162/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5;, score=0.777 total time=   0.0s
# [CV 2/5; 162/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5
# [CV 2/5; 162/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5;, score=0.705 total time=   0.0s
# [CV 3/5; 162/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5
# [CV 3/5; 162/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5;, score=0.676 total time=   0.0s
# [CV 4/5; 162/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5
# [CV 4/5; 162/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5;, score=0.757 total time=   0.0s
# [CV 5/5; 162/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5
# [CV 5/5; 162/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5;, score=0.658 total time=   0.0s
# [CV 1/5; 163/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10
# [CV 1/5; 163/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10;, score=0.821 total time=   0.0s
# [CV 2/5; 163/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10
# [CV 2/5; 163/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10;, score=0.741 total time=   0.0s
# [CV 3/5; 163/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10
# [CV 3/5; 163/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10;, score=0.757 total time=   0.0s
# [CV 4/5; 163/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10
# [CV 4/5; 163/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10;, score=0.730 total time=   0.0s
# [CV 5/5; 163/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10
# [CV 5/5; 163/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10;, score=0.721 total time=   0.0s
# [CV 1/5; 164/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15
# [CV 1/5; 164/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15;, score=0.768 total time=   0.0s
# [CV 2/5; 164/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15
# [CV 2/5; 164/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15;, score=0.786 total time=   0.0s
# [CV 3/5; 164/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15
# [CV 3/5; 164/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15;, score=0.811 total time=   0.0s
# [CV 4/5; 164/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15
# [CV 4/5; 164/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15;, score=0.775 total time=   0.0s
# [CV 5/5; 164/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15
# [CV 5/5; 164/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15;, score=0.739 total time=   0.0s
# [CV 1/5; 165/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25
# [CV 1/5; 165/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25;, score=0.830 total time=   0.0s
# [CV 2/5; 165/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25
# [CV 2/5; 165/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25;, score=0.759 total time=   0.0s
# [CV 3/5; 165/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25
# [CV 3/5; 165/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25;, score=0.775 total time=   0.0s
# [CV 4/5; 165/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25
# [CV 4/5; 165/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25;, score=0.757 total time=   0.0s
# [CV 5/5; 165/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25
# [CV 5/5; 165/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25;, score=0.694 total time=   0.0s
# [CV 1/5; 166/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50
# [CV 1/5; 166/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50;, score=0.821 total time=   0.0s
# [CV 2/5; 166/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50
# [CV 2/5; 166/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50;, score=0.759 total time=   0.0s
# [CV 3/5; 166/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50
# [CV 3/5; 166/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50;, score=0.793 total time=   0.0s
# [CV 4/5; 166/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50
# [CV 4/5; 166/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50;, score=0.784 total time=   0.0s
# [CV 5/5; 166/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50
# [CV 5/5; 166/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50;, score=0.721 total time=   0.2s
# [CV 1/5; 167/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60
# [CV 1/5; 167/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60;, score=0.812 total time=   0.1s
# [CV 2/5; 167/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60
# [CV 2/5; 167/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60;, score=0.804 total time=   0.1s
# [CV 3/5; 167/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60
# [CV 3/5; 167/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60;, score=0.811 total time=   0.1s
# [CV 4/5; 167/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60
# [CV 4/5; 167/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60;, score=0.784 total time=   0.1s
# [CV 5/5; 167/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60
# [CV 5/5; 167/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60;, score=0.730 total time=   0.1s
# [CV 1/5; 168/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70
# [CV 1/5; 168/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70;, score=0.804 total time=   0.1s
# [CV 2/5; 168/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70
# [CV 2/5; 168/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70;, score=0.768 total time=   0.1s
# [CV 3/5; 168/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70
# [CV 3/5; 168/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70;, score=0.802 total time=   0.1s
# [CV 4/5; 168/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70
# [CV 4/5; 168/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70;, score=0.748 total time=   0.1s
# [CV 5/5; 168/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70
# [CV 5/5; 168/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70;, score=0.739 total time=   0.1s
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True], 'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 20, 40, 50, 60],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [5, 10, 15, 25, 50, 60, 70]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'entropy',
#  'max_depth': 60,
#  'max_features': 'auto',
#  'n_estimators': 25}

# %% [markdown]
# # final model

# %%
Final_mod = RandomForestClassifier(bootstrap=True,criterion='entropy',n_estimators= 50, max_depth=20 ,max_features='auto')
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
# Out:
# Accuracy Score :
#  0.8200836820083682

# %% [markdown]
# # Saving model

# %%
import joblib
joblib.dump(Final_mod,'Loan_Status_Final.pkl')
# Out:
# ['Loan_Status_Final.pkl']
